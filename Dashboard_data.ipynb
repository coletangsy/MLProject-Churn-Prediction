# %%
import pandas as pd
import numpy as np
import pickle

# %%
df = pd.read_csv("./data/telecom-churn_dummies.csv")
model = pickle.load(open('telecom_churn_best_model.sav', 'rb'))
# Out:
# C:\Users\tsyco\anaconda3\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.22.2.post1 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# C:\Users\tsyco\anaconda3\lib\site-packages\sklearn\base.py:310: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.22.2.post1 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
df.head()
# Out:
#    Unnamed: 0  SeniorCitizen  MonthlyCharges  TotalCharges  Churn  \
# 0           0              0           29.85         29.85      0
# 1           1              0           56.95       1889.50      0
# 2           2              0           53.85        108.15      1
# 3           3              0           42.30       1840.75      0
# 4           4              0           70.70        151.65      1
#
#    gender_Female  gender_Male  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0              1            0           0            1              1  ...
# 1              0            1           1            0              1  ...
# 2              0            1           1            0              1  ...
# 3              0            1           1            0              1  ...
# 4              1            0           1            0              1  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                        0
# ...

# %%
df.drop(columns=["Churn","Unnamed: 0"],inplace=True)
df.head()
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0              0           29.85         29.85              1            0
# 1              0           56.95       1889.50              0            1
# 2              0           53.85        108.15              0            1
# 3              0           42.30       1840.75              0            1
# 4              0           70.70        151.65              1            0
#
#    Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  PhoneService_No  \
# 0           0            1              1               0                1
# 1           1            0              1               0                0
# 2           1            0              1               0                0
# 3           1            0              1               0                1
# 4           1            0              1               0                0
#
#    ...  PaymentMethod_Bank transfer (automatic)  \
# ...

# %%
df2 = df[["Contract_Month-to-month","TotalCharges","OnlineSecurity_No","TechSupport_No","OnlineBackup_No","PaymentMethod_Electronic check", "DeviceProtection_No","Contract_Two year","tenure_group_1 - 12","MonthlyCharges"]]

# %%
df2
# Out:
#       Contract_Month-to-month  TotalCharges  OnlineSecurity_No  \
# 0                           1         29.85                  1
# 1                           0       1889.50                  0
# 2                           1        108.15                  0
# 3                           0       1840.75                  0
# 4                           1        151.65                  1
# ...                       ...           ...                ...
# 7027                        0       1990.50                  0
# 7028                        0       7362.90                  1
# 7029                        1        346.45                  0
# 7030                        1        306.60                  1
# 7031                        0       6844.50                  0
#
#       TechSupport_No  OnlineBackup_No  PaymentMethod_Electronic check  \
# 0                  1                0                               1
# ...

# %%
df["Predicted_Churn"] = model.predict(df2)

# %%
df["Predicted_Churn_rate"] = model.predict_proba(df2)[:,1]

# %%
df.to_csv("telecom-churn_dashboard.csv",index=False)
